# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("jamesleslie/titanic-cleaned-data")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/titanic-cleaned-data

# %%
import seaborn as sns
import pandas as pd
import os
# os.listdir(path +'train_clean.csv')
df = pd.read_csv(path +'/train_clean.csv')
# df = sns.load_dataset("titanic")
# print(df.head())
data = df[['PassengerId','Survived','Pclass','Age', 'SibSp','Parch','Fare']]
df
# Out:
#       Age Cabin Embarked     Fare  \
# 0    22.0   NaN        S   7.2500
# 1    38.0   C85        C  71.2833
# 2    26.0   NaN        S   7.9250
# 3    35.0  C123        S  53.1000
# 4    35.0   NaN        S   8.0500
# ..    ...   ...      ...      ...
# 886  27.0   NaN        S  13.0000
# 887  19.0   B42        S  30.0000
# 888  22.0   NaN        S  23.4500
# 889  26.0  C148        C  30.0000
# 890  32.0   NaN        Q   7.7500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
# ..                                                 ...    ...          ...
# 886                              Montvila, Rev. Juozas      0          887
# 887                       Graham, Miss. Margaret Edith      0          888
# 888           Johnston, Miss. Catherine Helen "Carrie"      2          889
# 889                              Behr, Mr. Karl Howell      0          890
# 890                                Dooley, Mr. Patrick      0          891
#
#      Pclass     Sex  SibSp  Survived            Ticket Title  Family_Size
# 0         3    male      1       0.0         A/5 21171    Mr            1
# 1         1  female      1       1.0          PC 17599   Mrs            1
# 2         3  female      0       1.0  STON/O2. 3101282  Miss            0
# 3         1  female      1       1.0            113803   Mrs            1
# 4         3    male      0       0.0            373450    Mr            0
# ..      ...     ...    ...       ...               ...   ...          ...
# 886       2    male      0       0.0            211536   Rev            0
# 887       1  female      0       1.0            112053  Miss            0
# 888       3  female      1       0.0        W./C. 6607  Miss            3
# 889       1    male      0       1.0            111369    Mr            0
# 890       3    male      0       0.0            370376    Mr            0
#
# [891 rows x 14 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
# Set a visual style
sns.set_style("whitegrid")

# %%
# Histograms for numerical features
df.hist(figsize=(12, 8), bins=20, edgecolor='black', layout=(3, 3))
plt.suptitle("Distribution of Numerical Features", fontsize=16)
plt.show()

# %%
# Box plots for Age and Fare to identify outliers
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
sns.boxplot(y=df["Age"], ax=axes[0], palette="pastel")
axes[0].set_title("Box Plot of Age")
# Box plots for Age and Fare to identify outliers
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
sns.boxplot(y=df["Fare"], ax=axes[0], palette="pastel")
axes[1].set_title("Box Plot of Fare")
# Out:
# <ipython-input-77-06fb5faa485d>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=df["Age"], ax=axes[0], palette="pastel")
# <ipython-input-77-06fb5faa485d>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=df["Fare"], ax=axes[0], palette="pastel")
# Text(0.5, 1.0, 'Box Plot of Fare')

# %%
# Box plots for Age and Fare to identify outliers
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
sns.boxplot(y=df["Fare"], ax=axes[0], palette="pastel")
axes[0].set_title("Box Plot of Age")
# Out:
# <ipython-input-78-717154684413>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=df["Fare"], ax=axes[0], palette="pastel")
# Text(0.5, 1.0, 'Box Plot of Age')

# %%
sns.boxplot(y=df["Fare"], ax=axes[1], palette="pastel")
axes[1].set_title("Box Plot of Fare")
plt.show()
# Out:
# <ipython-input-79-2e098cbe700e>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y=df["Fare"], ax=axes[1], palette="pastel")

# %%
# Heatmap to show correlations
plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
# Bar plot for survival rate by Sex
plt.figure(figsize=(8, 5))
sns.barplot(x="Sex", y="Survived", data=df, palette="coolwarm")
plt.title("Survival Rate by Sex")
plt.ylabel("Survival Rate")
plt.show()
# Out:
# <ipython-input-83-989d59f6b386>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Sex", y="Survived", data=df, palette="coolwarm")

# %%
# Pclass
plt.figure(figsize=(8, 5))
sns.barplot(x="Pclass", y="Survived", data=df, palette="coolwarm")
plt.title("Survival Rate by Passenger Class")
plt.ylabel("SurvivalRate")
plt.show()
# Out:
# <ipython-input-85-16f6de131d48>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Pclass", y="Survived", data=df, palette="coolwarm")

# %%
# Bar plot for survival rate by Embarked location
plt.figure(figsize=(8, 5))
sns.barplot(x="Embarked", y="Survived", data=df, palette="coolwarm")
plt.title("Survival Rate by Embarkation Port")
plt.ylabel("Survival Rate")
plt.show()
# Out:
# <ipython-input-89-f4c81b6815d2>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Embarked", y="Survived", data=df, palette="coolwarm")

# %%
# Stacked bar plot for survival by class and gender
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x="Pclass", hue="Sex", multiple="stack", palette="coolwarm", bins=3)
plt.title("Survival Distribution by Class and Gender")
plt.xlabel("Passenger Class")
plt.ylabel("Count")
plt.show()

# %%
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(" ".join(df["Name"]))
# Plot the word cloud
plt.figure(figsize=(10,5))
plt.imshow(wordcloud,
interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of Passenger Names")
plt.show()
